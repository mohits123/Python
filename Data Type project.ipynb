# %%
while(True):
    print("\nMAIN MENU")
    print("--------------")
    print("1. List\n2. Tuple\n3. Dictionary\n4. Set\n5.Exit:Enter-0\n")
    print("--------------")

    ch=int(input("Enter your choice from main menu:"))
    

    ifp ch==1:
        while(True):
            print("\nLIST OPERATIONS")
            print("--------------")

            print("1.Definition\n2.Add elements to the list\n3.Deletion\n4.Exit:Enter-0\n")
            ch1 = int(input("Enter your choice: "))



            if ch1==1:
                print("A list is a collection of items that are ordered and changeable.")
            elif ch1==2:
                print("ADD ELEMENTS TO THE LIST")
                print("--------------")
                my_list=list=[1,2,3,4,5,6,7,8,9]
                print("1.Add a single element\n2.Add multiple elements\n3.Do you want to add element at specific index position")
                ch2=int(input("Enter your choice: "))

                if ch2==1:
                    element=int(input("Enter a element to add:-"))
                    my_list.append(element)
                    print(my_list)
                elif ch2==2:
                    element=input("Enter multiple elements seperated by comma:")
                    my_list.extend(element.split(","))
                    print(my_list)
                elif ch2==3:
                    element=input("Enter element to add: ")
                    index=int(input("Enter index value for adding element to specific position"))
                    my_list.insert(index,element)
                    print(my_list)
                else:
                    print("Invalid choice")

            elif ch1==3:
                print("DELETE ELEMENT FROM LISt")
                print("--------------")
                my_list=list(input("Enter your list: "))
                print("1.Delete a single element\n2.Delete an element at specific index position")
                ch2=int(input("Enter your choice: "))

                if ch2==1:
                    element=input("Enter the element to delete: ")
                    my_list.remove(element)
                    print(my_list)
                elif ch2==2:
                    index=int(input("Enter the index position: "))
                    my_list.pop(index)
                    print(my_list)
                else:
                    print("Invalid choice")

            elif ch1==0:
                print("Exited going back to main menu")
                break
            else:
                print("invalid choice")

    elif ch==2:
        while(True):
            print("\nTUPLE OPERATIONS")
            print("--------------")
            print("1.Definition\n2.Add elements to the tuple\n3.Deletion\n4.Exit:Enter-0\n")
            ch1=int(input("Enetr your choice"))



            if ch1==1:
                print("A tuple is a collection of items that are ordered and unchangeable.")
            elif ch1==2:
                print("ADD ELEMENTS TO THE TUPLE")
                print("--------------")
                my_tup=tuple(input("Enter tuple: "))
                print("1.Add single element\n2.Add multiple element\n3.Add element using specific position")
                ch2=int(input("Enetr your choice"))

                if ch2==1:
                    element=input("Enter element to be added")
                    l=list(my_tup)
                    l.append(element)
                    a=tuple(l)
                    print(a)
                elif ch2==2:
                    element=input("Enter multiple elements seperated by comma:")
                    l=list(my_tup)
                    l.extend(element.split(","))
                    a=tuple(l)
                    print(a)
                elif ch2==3:
                    element=input("Enter element to add: ")
                    l=list(my_tup)
                    index=int(input("Enter index value for adding element to specific position"))
                    l.insert(index,element)
                    a=tuple(l)
                    print(a)
            elif ch1==3:
                print("DELETE ELEMENT FROM TUPLE")
                print("--------------")
                my_tup=tuple(input("Enter tuple: "))
                print("1.Delete a single element\n2.Delete an element at specific index position")
                ch2=int(input("Enter your choice: "))

                if ch2==1:
                    element=input("Enter the element to delete: ")
                    l=list(my_tup)
                    l.remove(element)
                    a=tuple(l)
                    print(a)
                elif ch2==2:
                    index=int(input("Enter the index position: "))
                    l=list(my_tup)
                    l.pop(index)
                    a=tuple(l)
                    print(a)
                else:
                    print("Invalid choice")
            elif ch1==0:
                print("Exited going back to main menu")
                break
            else:
                print("Invalid choice")
                
    elif ch==3:
        while(True):
            print("\nDICTIONARY OPERATIONS")
            print("---------------------")
            print("1. Definition\n2. Add an item to the dictionary\n3. Delete an item from the dictionary\n4. Access a element from the dictionary\n5. View all items in the dictionary\n6.Exit:Enter-0\n")
            ch1 = int(input("Enter your choice: "))


            if ch1==1:
                print("A dictionary is a collection of key-value pairs that are ordered and changeable.")
            elif ch1 == 2:
                my_dict = {}

                for i in range(3):
                    k = input("Enter key: ")
                    v = input("Enter key_value: ")

                    my_dict[k] = v

                print(my_dict)

                key = input("Enter the key to be added: ")
                value = input("Enter the added key_value: ")
                my_dict[key] = value
                print(my_dict)
            elif ch1 == 3:
                my_dict = {}

                for i in range(3):
                    k = input("Enter key: ")
                    v = input("Enter key_value: ")

                    my_dict[k] = v

                print(my_dict)

                key = input("Enter the key to delete from dictionary: ")
                del my_dict[key]
                print(my_dict)
            elif ch1 == 4:
                my_dict = {}

                for i in range(3):
                    k = input("Enter key: ")
                    v = input("Enter key_value: ")

                    my_dict[k] = v

                print(my_dict)

                key = input("Enter the key to access : ")
                print("The value for the key", key, "is", my_dict[key])
            elif ch1 == 5:
                my_dict = {}

                for i in range(3):
                    k = input("Enter key: ")
                    v = input("Enter key_value: ")

                    my_dict[k] = v

                print(my_dict)

                print("The items in the dictionary are:")
                for key, value in my_dict.items():
                    print(key, ":", value)
            elif ch1==0:
                print("Exited going back to main menu")
                break
            else:
                print("Invalid choice. Please try again.")
                
    
    elif ch == 4:
        while(True):
            print("\nSET OPERATIONS")
            print("--------------")
            print("1. Definition\n2. Add an item to the set\n3. Remove an item from the set\n4.Exit:Enter-0\n")
            ch1 = int(input("Enter your choice: "))



            if ch1 == 1:
                print("A set is a collection of unique items that are unordered and unindexed.")
            elif ch1 == 2:
                print("ADD ELEMENTS TO THE SET")
                print("--------------")
                my_set = set(input("Enter a set: "))
                print("1.Add single element\n2.Add multiple element")
                ch2=int(input("Enetr your choice"))

                if ch2==1:

                    item = input("Enter the item:")
                    my_set.add(item)
                    print(my_set)
                elif ch2==2:
                    l=list(input("Enter multiple elements: "))
                    my_set.update(l)
                    print(my_set)
                else:
                    print("Invalid choice")
            elif ch1 == 3:
                print("DELETE ELEMENT FROM SET")
                print("--------------")
                my_set = set(input("Enter a set: "))
                print("1.Delete a single element\n2.Delete an random element from set")
                ch2=int(input("Enter your choice: "))

                if ch2==1:    
                    item = input("Enter the item: ")
                    my_set.remove(item)
                    print(my_set)

                elif ch2==2:
                    my_set.pop()
                    print(my_set)
                else:
                    print("Invalid choice")

            elif ch1==0:
                print("Exited going back to main menu")
                break
            else:
                print("Invalid choice. Please try again.")
                
    elif ch==0:
        print("Menu Closed")
        break
    else:
        print("Invalid choice")
# Out:
# MAIN MENU
# --------------
# 1. List
# 2. Tuple
# 3. Dictionary
# 4. Set
# 5.Exit:Enter-0
#
# --------------
